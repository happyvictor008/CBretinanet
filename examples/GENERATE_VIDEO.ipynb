# %%
# show images inline
# %matplotlib inline

# automatically reload modules when they have changed
# %load_ext autoreload
# %autoreload 2

# import keras
import keras
# import miscellaneous modules
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import time
import mmcv
# set tf backend to allow memory to grow, instead of claiming everything
import tensorflow as tf
# import keras_retinanet
from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color
from keras_retinanet.utils.gpu import setup_gpu
from keras_retinanet.utils.visual import draw_caption1



def get_session():
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    return tf.Session(config=config)

# use this to change which GPU to use
gpu = 0

# set the modified tf session as backend in keras
setup_gpu(gpu)
# Out:
# Using TensorFlow backend.
# 1 Physical GPUs, 1 Logical GPUs

# %%
# adjust this to point to your downloaded/trained model
# models can be downloaded here: https://github.com/fizyr/keras-retinanet/releases
#model_path = os.path.join('..', 'snapshots', 'resnet50_coco_best_v2.1.0.h5')
model_path = 'C:\\Users\\14590\\Downloads\\models\\vis-new.h5'

# load retinanet model
model = models.load_model(model_path, backbone_name='resnet101')

# if the model is not converted to an inference model, use the line below
# see: https://github.com/fizyr/keras-retinanet#converting-a-training-model-to-inference-model
#model = models.convert_model(model)

#print(model.summary())

# load label to names mapping for visualization purposes
#labels_to_names = {0: 'None', 1: 'pedestrian', 2: 'people', 3: 'bicycle', 4: 'car', 5: 'van', 6: 'truck', 7: 'tricycle', 8: 'awning-tricycle', 9: 'bus', 10: 'motor', 11:'others'}
labels_to_names = {0: 'Ignored region',1: 'pedestrian', 2: 'people', 3: 'bicycle', 4: 'car', 5: 'van', 6: 'truck', 7: 'tricycle', 8: 'awning-tricycle', 9: 'bus', 10: 'motor',11:'others'}
# Out:
# ________________________________________________________init__________________________________________
# {'UpsampleLike': <class 'keras_retinanet.layers._misc.UpsampleLike'>, 'PriorProbability': <class 'keras_retinanet.initializers.PriorProbability'>, 'RegressBoxes': <class 'keras_retinanet.layers._misc.RegressBoxes'>, 'FilterDetections': <class 'keras_retinanet.layers.filter_detections.FilterDetections'>, 'Anchors': <class 'keras_retinanet.layers._misc.Anchors'>, 'ClipBoxes': <class 'keras_retinanet.layers._misc.ClipBoxes'>, '_smooth_l1': <function smooth_l1.<locals>._smooth_l1 at 0x000001EFA3C0A048>, '_focal': <function focal.<locals>._focal at 0x000001EFA3C0A0D8>}
# 12121212121211212121121
# None
# 12121212121211212121121
# return model
# tracking <tf.Variable 'Variable:0' shape=(12, 4) dtype=float32, numpy=
# array([[-11.313708,  -5.656854,  11.313708,   5.656854],
#        [-13.57645 ,  -6.788225,  13.57645 ,   6.788225],
# ...

# %%
# adjust this to point to your downloaded/trained model
# models can be downloaded here: https://github.com/fizyr/keras-retinanet/releases
model_path = os.path.join('/home/victor/keras-retinanet/', 'snapshots', 'resnet50_visdataset_50.h5')

# load retinanet model
model = models.load_model(model_path, backbone_name='resnet50')

# if the model is not converted to an inference model, use the line below
# see: https://github.com/fizyr/keras-retinanet#converting-a-training-model-to-inference-model
model = models.convert_model(model)

#print(model.summary())

# load label to names mapping for visualization purposes
labels_to_names = {0: 'Ignored Region ', 1: 'Pedestrian', 2: 'People', 3: 'cyclist', 4: 'Car', 5: 'Vans', 6: 'Truck', 7: 'Tricyclist', 8: 'Awning-Tricyclist', 9: 'Bus', 10: 'Motor', 11: 'Others'}
# Out:
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[-22.627417, -11.313708,  22.627417,  11.313708],
#        [-28.50876 , -14.25438 ,  28.50876 ,  14.25438 ],
#        [-35.918785, -17.959393,  35.918785,  17.959393],
#        [-16.      , -16.      ,  16.      ,  16.      ],
#        [-20.158737, -20.158737,  20.158737,  20.158737],
#        [-25.398417, -25.398417,  25.398417,  25.398417],
#        [-11.313708, -22.627417,  11.313708,  22.627417],
#        [-14.25438 , -28.50876 ,  14.25438 ,  28.50876 ],
#        [-17.959393, -35.918785,  17.959393,  35.918785]], dtype=float32)> anchors
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[-45.254833, -22.627417,  45.254833,  22.627417],
#        [-57.01752 , -28.50876 ,  57.01752 ,  28.50876 ],
#        [-71.83757 , -35.918785,  71.83757 ,  35.918785],
#        [-32.      , -32.      ,  32.      ,  32.      ],
#        [-40.317474, -40.317474,  40.317474,  40.317474],
# ...

# %%
# adjust this to point to your downloaded/trained model
# models can be downloaded here: https://github.com/fizyr/keras-retinanet/releases
model_path = os.path.join('/home/victor/keras-retinanet/', 'snapshots', 'resnet50_kitti_31.h5')

# load retinanet model
model = models.load_model(model_path, backbone_name='resnet50')

# if the model is not converted to an inference model, use the line below
# see: https://github.com/fizyr/keras-retinanet#converting-a-training-model-to-inference-model
model = models.convert_model(model)

#print(model.summary())

# load label to names mapping for visualization purposes
labels_to_names = {0: 'Car', 1: 'Van', 2: 'Truck', 3: 'Pedestrian', 4: 'Person_sitting', 5: 'Cyclist', 6: 'Tram', 7: 'DontCare'}
# Out:
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[-22.627417, -11.313708,  22.627417,  11.313708],
#        [-28.50876 , -14.25438 ,  28.50876 ,  14.25438 ],
#        [-35.918785, -17.959393,  35.918785,  17.959393],
#        [-16.      , -16.      ,  16.      ,  16.      ],
#        [-20.158737, -20.158737,  20.158737,  20.158737],
#        [-25.398417, -25.398417,  25.398417,  25.398417],
#        [-11.313708, -22.627417,  11.313708,  22.627417],
#        [-14.25438 , -28.50876 ,  14.25438 ,  28.50876 ],
#        [-17.959393, -35.918785,  17.959393,  35.918785]], dtype=float32)> anchors
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[-45.254833, -22.627417,  45.254833,  22.627417],
#        [-57.01752 , -28.50876 ,  57.01752 ,  28.50876 ],
#        [-71.83757 , -35.918785,  71.83757 ,  35.918785],
#        [-32.      , -32.      ,  32.      ,  32.      ],
#        [-40.317474, -40.317474,  40.317474,  40.317474],
# ...

# %%
path='C:\\Users\\14590\\Desktop\\victor\\results\\video\\ori.mp4' 
video = mmcv.VideoReader(path)

# %%
i=0
for image in video:
    # copy to draw on
    draw = image.copy()
    draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)

# preprocess image for network
    image = preprocess_image(image)
    image, scale = resize_image(image)

# process image
    start = time.time()
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
    print("processing time: ", time.time() - start)

# correct for image scale
    boxes /= scale

# visualize detections
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
    # scores are sorted so we can break
        if score < 0.5:
            break
        
        color = label_color(label)
    
        b = box.astype(int)
        draw_box(draw, b, color=color,thickness=2)
    
        caption = "{} {:.3f}".format(labels_to_names[label], score)
        #print(caption)
        draw_caption1(draw, b, caption,size=2,thickness=2,R=255,G=255,B=0)
    #cv2.imwrite('/home/victor/keras-retinanet/result'+caption+'.jpg',draw1)
    

    save_img=cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)
    cv2.imwrite('C:\\Users\\14590\\Desktop\\victor\\results\\videoframe\\'+str(i).zfill(6)+'.jpg',save_img)
    i=i+1
# Out:
# processing time:  0.1270289421081543
# processing time:  0.10202288627624512
# processing time:  0.09602141380310059
# processing time:  0.09402179718017578
# processing time:  1.3026494979858398
# processing time:  0.09402108192443848
# processing time:  0.12502789497375488
# processing time:  0.11402678489685059
# processing time:  0.10102295875549316
# processing time:  0.09402108192443848
# processing time:  0.11502623558044434
# processing time:  0.10102272033691406
# processing time:  0.09302163124084473
# processing time:  0.09302067756652832
# processing time:  0.1490340232849121
# processing time:  0.09202170372009277
# processing time:  0.11402654647827148
# processing time:  0.1180267333984375
# processing time:  0.09402179718017578
# processing time:  0.24594330787658691
# processing time:  0.10102319717407227
# processing time:  0.12781071662902832
# processing time:  0.09302186965942383
# processing time:  0.169877290725708
# processing time:  0.10402417182922363
# ...

# %%
#############visdataset
path='/home/victor/Downloads/VisDrone2019-VID-test-challenge/sequences/uav0000105_03338_v/'
imgnum=1000

# %%
###################visdataset

i=1

for i in range(1,208):
    image = read_image_bgr(path+str(i).zfill(7)+'.jpg')
    # copy to draw on
    draw = image.copy()
    draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)

# preprocess image for network
    image = preprocess_image(image)
    image, scale = resize_image(image)

# process image
    start = time.time()
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
    print("processing time: ", time.time() - start)

# correct for image scale
    boxes /= scale

# visualize detections
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
    # scores are sorted so we can break
        if score < 0.6:
            break
        
        color = label_color(label)
    
        b = box.astype(int)
        draw_box(draw, b, color=color,thickness=2)
    
        caption = "{} {:.3f}".format(labels_to_names[label], score)
        #print(caption)
        draw_caption1(draw, b, caption,size=2,thickness=2,R=255,G=255,B=0)
    #cv2.imwrite('/home/victor/keras-retinanet/result'+caption+'.jpg',draw1)
    

    save_img=cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)
    cv2.imwrite('/home/victor/Frame/cvt_frame/'+str(i-1).zfill(6)+'.jpg',save_img)
    i=i+1
# Out:
# processing time:  1.1939008235931396
# processing time:  1.278411865234375
# processing time:  1.2831597328186035
# processing time:  1.269714117050171
# processing time:  1.2640910148620605
# processing time:  1.268697738647461
# processing time:  1.2715697288513184
# processing time:  1.2656526565551758
# processing time:  1.2714154720306396
# processing time:  1.266061782836914
# processing time:  1.2683827877044678
# processing time:  1.269693374633789
# processing time:  1.2586755752563477
# processing time:  1.2677900791168213
# processing time:  1.265547513961792
# processing time:  1.2680463790893555
# processing time:  1.2543578147888184
# processing time:  1.2655010223388672
# processing time:  1.264038324356079
# processing time:  1.2619149684906006
# processing time:  1.2640380859375
# processing time:  1.2599217891693115
# processing time:  1.2587785720825195
# processing time:  1.2622244358062744
# processing time:  1.2702996730804443
# ...

# %%
mmcv.frames2video('C:\\Users\\14590\\Desktop\\victor\\results\\videoframe\\', 'C:\\Users\\14590\\Desktop\\victor\\results\\oridec.mp4')
# Out:
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 5985/5985, 32.0 task/s, elapsed: 187s, ETA:     0s

# %%
mmcv.frames2video('/home/victor/Downloads/VisDrone2019-VID-test-challenge/sequences/uav0000006_06900_v/', '/home/victor/Downloads/VisDrone2019-VID-test-challenge/sequences/uav0000006_06900_v/drone.mp4')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-1e70c43585a2> in <module>
# ----> 1 mmcv.frames2video('/home/victor/Downloads/VisDrone2019-VID-test-challenge/sequences/uav0000006_06900_v/', '/home/victor/Downloads/VisDrone2019-VID-test-challenge/sequences/uav0000006_06900_v/drone.mp4')
#
# ~/retinanet/lib/python3.6/site-packages/mmcv/video/io.py in frames2video(frame_dir, video_file, fps, fourcc, filename_tmpl, start, end, show_progress)
#     312         end = len([name for name in scandir(frame_dir, ext)])
#     313     first_file = osp.join(frame_dir, filename_tmpl.format(start))
# --> 314     check_file_exist(first_file, 'The start frame not found: ' + first_file)
#     315     img = cv2.imread(first_file)
#     316     height, width = img.shape[:2]
#
# ~/retinanet/lib/python3.6/site-packages/mmcv/utils/path.py in check_file_exist(filename, msg_tmpl)
# ...

# %%
video.cvt2frames('/home/victor/Frame/video/report/')
# Out:
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 1335/1335, 75.5 task/s, elapsed: 18s, ETA:     0s
